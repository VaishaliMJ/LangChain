# %%
import os
from dotenv import load_dotenv

load_dotenv()

# %%
GROQ_API_KEY=os.getenv("GROQ_API_KEY")
GROQ_API_KEY

# %%
from langchain_groq import ChatGroq

model=ChatGroq(model="llama-3.3-70b-versatile",groq_api_key=GROQ_API_KEY)

# %%
model

# %%
from langchain_core.messages import HumanMessage
model.invoke([HumanMessage(content="Hi,I am Vaishali and I have completed Python,ML,DL,GenAI Course.")])

# %%
from langchain_core.messages import AIMessage
model.invoke(
    [
        HumanMessage(content="Hi,I am Vaishali and I have completed Python,ML,DL,GenAI Course."),
        AIMessage(content="Hi Vaishali, congratulations on completing your courses in Python, Machine Learning, Deep Learning, and General Artificial Intelligence! That's a significant achievement. \n\nWhat are your plans now? Are you looking to apply your skills in a specific industry or work on personal projects? Or do you have any specific topics or areas you'd like to explore further? I'm here to help and provide guidance if you need it."),
        HumanMessage(content="What is my name and what i do?")
    
    ]
)

# %% [markdown]
# ### Message History

# %%
from langchain_community.chat_message_histories import ChatMessageHistory
from langchain_core.chat_history import BaseChatMessageHistory
from langchain_core.runnables.history import RunnableWithMessageHistory

sessionIdStore={}
# User Session
def getSessionHistory(session_id:str)->BaseChatMessageHistory:
    if session_id not in sessionIdStore:
        sessionIdStore[session_id]=ChatMessageHistory()
    return sessionIdStore[session_id] 


with_message_history=RunnableWithMessageHistory(model,getSessionHistory)

# %%
config={"configurable":{"session_id":"chat1"}}

# %%
response=with_message_history.invoke(
    [HumanMessage(content="Hi,I am Vaishali and I have completed Python,ML,DL,GenAI Course.")],
    config=config
    
)

# %%
response.content

# %%
config1={"configurable":{"session_id":"chat2"}}
response=with_message_history.invoke(
    [HumanMessage(content="What is my name?")],
    config=config1
)

response.content

# %%
response=with_message_history.invoke(
    [HumanMessage(content="Hello,My name is Siya")],
    config=config1
)

response.content

# %%
response=with_message_history.invoke(
    [HumanMessage(content="What is my name?")],
    config=config1
)

response.content
